# %% [markdown]
# # <strong><font color="f0b9cf">**Telecom X - Análisis de Evasión de Clientes**</font></strong>
#
# ---

# %% [markdown]
# <img src="https://raw.githubusercontent.com/Belita-Lili/telecom-data-science-alura/refs/heads/main/PaletaDeColotes/TelecomX_ChatGPT.png" alt="inserir alt" width=800>
#
# Has sido contratado como asistente de análisis de datos en Telecom X y formarás parte del proyecto "Churn de Clientes". La empresa enfrenta una alta tasa de cancelaciones y necesita comprender los factores que llevan a la pérdida de clientes.
#
# Tu desafío será recopilar, procesar y analizar los datos, utilizando Python y sus principales bibliotecas para extraer información valiosa. A partir de tu análisis, el equipo de Data Science podrá avanzar en modelos predictivos y desarrollar estrategias para reducir la evasión.
#
# ¿Qué vas a practicar?
# * ✅ Importar y manipular datos desde una API de manera eficiente.
# * ✅ Aplicar los conceptos de ETL (Extracción, Transformación y Carga) en la preparación de los datos.
# * ✅ Crear visualizaciones estratégicas para identificar patrones y tendencias.
# * ✅ Realizar un Análisis Exploratorio de Datos (EDA) y generar un informe con insights relevantes.
#
# ¡Ahora es tu turno! 🚀 Usa tus conocimientos para transformar datos en información estratégica y ayudar a Telecom X a retener más clientes.

# %% [markdown]
# # **Indice**
#
# - [Paleta de Colores)](#toc1_)
#   - [Paleta del proyecto](#toc1_1_)
# - [Extracción](#toc2_)
# - [Importar y explorar datos](#toc3_)
# - [Limpieza de Datos para el DataFrame "ACCOUNT"](#toc4_)
#   - [Limpieza de valores categóricos](#toc4_1_)
#   - [Limpieza de columnas numéricas](#toc4_2_)
#   - [Crear columnas Cuentas_Diarias](#toc4_3_)
#   - [Análisis descriptivo básico](#toc4_4_)
#   - [Visualización rápida](#toc4_5_)
# - [Limpieza de Datos para el DataFrame "CUSTOMER"](#toc5_)
#   - [Limpieza de valores categoricos](#toc5_1_)
#   - [Revisión de valores faltantes o inconsistencias](#toc5_2_)
#   - [Análisis descriptivo](#toc5_3_)
#   - [Análisis exploratorio: ¿quiénes cancelan más?](#toc5_4)
# - [Transformación](#toc6_)
# - [Carga y análisis](#toc7_)
# - [Informe final](#toc8_)

# %% [markdown]
# # 🎨 Paleta de Colores

# %% [markdown]
# <img src="https://raw.githubusercontent.com/Belita-Lili/telecom-data-science-alura/refs/heads/main/PaletaDeColotes/Colores.png" alt="inserir alt" width=480>
#
# &nbsp;
#
# #### Paleta del proyecto
#
# |Rosa Lavanda|||
# |------|------|------|
# | Rosa_Lavanda|Lila_Suave |Violeta_Claro |
# |#e0d1ed | #b8a0d5 | #9280ba |
# | ![adicionar desc](https://raw.githubusercontent.com/Belita-Lili/telecom-data-science-alura/refs/heads/main/PaletaDeColotes/L1.png)  |![adicionar desc](https://raw.githubusercontent.com/Belita-Lili/telecom-data-science-alura/refs/heads/main/PaletaDeColotes/L2.png) |![adicionar desc](https://raw.githubusercontent.com/Belita-Lili/telecom-data-science-alura/refs/heads/main/PaletaDeColotes/L3.png) |
#
# &nbsp;
#
# |Rosa Claro|||
# |------|------|------|
# |Rosa Claro |Melocotón |Rosado Pastel |
# |#f0b9cf | #f9a89e| #f7c3b2 |
# | ![adicionar desc](https://raw.githubusercontent.com/Belita-Lili/telecom-data-science-alura/refs/heads/main/PaletaDeColotes/Rs1.png)  |![adicionar desc](https://raw.githubusercontent.com/Belita-Lili/telecom-data-science-alura/refs/heads/main/PaletaDeColotes/Rs2.png) |![adicionar desc](https://raw.githubusercontent.com/Belita-Lili/telecom-data-science-alura/refs/heads/main/PaletaDeColotes/Rs3.png) |
#
# &nbsp;
#
# |Magenta Claro|||
# |------|------|------|
# |Magenta_Claro |Rosa_Intenso |Rojo_Fucsia |
# |#e63c80 | #df2063| #ea027a |
# | ![adicionar desc](https://raw.githubusercontent.com/Belita-Lili/telecom-data-science-alura/refs/heads/main/PaletaDeColotes/R1.png)  |![adicionar desc](https://raw.githubusercontent.com/Belita-Lili/telecom-data-science-alura/refs/heads/main/PaletaDeColotes/R2.png) |![adicionar desc](https://raw.githubusercontent.com/Belita-Lili/telecom-data-science-alura/refs/heads/main/PaletaDeColotes/R3.png) |
#
# &nbsp;
#
# |Verde Botella||||||
# |------|------|------|------|------|------|
# |Negro Carbón| Carmesí |Rojo_Intenso |Púrpura_Oscuro |Borgoña |
# |#0a0c0d | #c70452 |#d7003a | #4b004c|#5a074b |
# |![adicionar desc](https://raw.githubusercontent.com/Belita-Lili/telecom-data-science-alura/refs/heads/main/PaletaDeColotes/colores_2.png)|

# %%
# Adicionamos los colores al proyecto
Rosa_Lavanda,Lila_Suave, Violeta_Claro = "#e0d1ed",	"#b8a0d5",	"#9280ba"
Rosa_Claro,	Melocotón,	Rosado_Pastel = "#f0b9cf",	"#f9a89e",	"#f7c3b2"
Magenta_Claro,	Rosa_Intenso,	Rojo_Fucsia = "#e63c80",	"#df2063",	"#ea027a"
Negro_Carbón,	Carmesí,	Rojo_Intenso,	Púrpura_Oscuro,	Borgoña	 = "#0a0c0d",	"#c70452",	"#d7003a",	"#4b004c",	"#5a074b"

# %% [markdown]
# #📌 Extracción

# %% [markdown]
# ## Importar y explorar datos

# %%
import pandas as pd
import requests
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Cargar datos desde GitHub
url = 'https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/main/TelecomX_Data.json'
datos = pd.read_json(url)
datos.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
phone = pd.json_normalize(datos['phone'])
phone.head()
# Out:
#   PhoneService MultipleLines
# 0          Yes            No
# 1          Yes           Yes
# 2          Yes            No
# 3          Yes            No
# 4          Yes            No

# %%
internet = pd.json_normalize(datos['internet'])
internet.head()
# Out:
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No         Yes
# 1             DSL             No           No               No          No
# 2     Fiber optic             No           No              Yes          No
# 3     Fiber optic             No          Yes              Yes          No
# 4     Fiber optic             No           No               No         Yes
#
#   StreamingTV StreamingMovies
# 0         Yes              No
# 1          No             Yes
# 2          No              No
# 3         Yes             Yes
# 4         Yes              No

# %%
customer = pd.json_normalize(datos['customer'])
customer.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure
# 0  Female              0     Yes        Yes       9
# 1    Male              0      No         No       9
# 2    Male              0      No         No       4
# 3    Male              1     Yes         No      13
# 4  Female              1     Yes         No       3

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   object
#  3   Dependents     7267 non-null   object
#  4   tenure         7267 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 284.0+ KB

# %%
columnas = list(customer.columns)
columnas
# Out:
# ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure']

# %%
df_customer = customer.explode(columnas[4:])
df_customer
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   object
#  3   Dependents     7267 non-null   object
#  4   tenure         7267 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 340.6+ KB

# %%
account = pd.json_normalize(datos['account'])
account.head()
# Out:
#          Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0        One year              Yes      Mailed check             65.6
# 1  Month-to-month               No      Mailed check             59.9
# 2  Month-to-month              Yes  Electronic check             73.9
# 3  Month-to-month              Yes  Electronic check             98.0
# 4  Month-to-month              Yes      Mailed check             83.9
#
#   Charges.Total
# 0         593.3
# 1         542.4
# 2        280.85
# 3       1237.85
# 4         267.4

# %%
account.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   object
#  2   PaymentMethod     7267 non-null   object
#  3   Charges.Monthly   7267 non-null   float64
#  4   Charges.Total     7267 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 284.0+ KB

# %%
columnas = list(account.columns)
columnas
# Out:
# ['Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Charges.Monthly',
#  'Charges.Total']

# %%
account.reset_index(inplace = True, drop = True)
df_account = account
df_account
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %%
df_account.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   object
#  2   PaymentMethod     7267 non-null   object
#  3   Charges.Monthly   7267 non-null   float64
#  4   Charges.Total     7267 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 284.0+ KB

# %% [markdown]
# ## Limpieza de Datos para el DataFrame "ACCOUNT"

# %% [markdown]
# ### 1. Limpieza de valores categóricos

# %%
# Verificar valores únicos en columnas categóricas
print(df_account['Contract'].unique())
print(df_account['PaperlessBilling'].unique())
print(df_account['PaymentMethod'].unique())
# Out:
# ['One year' 'Month-to-month' 'Two year']
# ['Yes' 'No']
# ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']

# %%
df_account['PaperlessBilling'] = df_account['PaperlessBilling'].replace({'Yes': 1, 'No': 0})
# Out:
# <ipython-input-58-e9dadb7bbf8c>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_account['PaperlessBilling'] = df_account['PaperlessBilling'].replace({'Yes': 1, 'No': 0})

# %% [markdown]
# ### 2. Limpieza de columnas numéricas

# %%
# Convertir a numérico y manejar errores
df_account['Charges.Monthly'] = pd.to_numeric(df_account['Charges.Monthly'], errors='coerce')
df_account['Charges.Total'] = pd.to_numeric(df_account['Charges.Total'], errors='coerce')

# Verificar valores faltantes
print(df_account[['Charges.Monthly', 'Charges.Total']].isnull().sum())
# Out:
# Charges.Monthly     0
# Charges.Total      11
# dtype: int64

# %% [markdown]
#  ### 3. Crear columna Cuentas_Diarias

# %%
df_account['Cuentas_Diarias'] = df_account['Charges.Monthly'] / 30

# %% [markdown]
# ### 4. Análisis descriptivo básico

# %%
# Estadísticas numéricas
print(df_account[['Charges.Monthly', 'Charges.Total', 'Cuentas_Diarias']].describe())
# Out:
#        Charges.Monthly  Charges.Total  Cuentas_Diarias
# count      7267.000000    7256.000000      7267.000000
# mean         64.720098    2280.634213         2.157337
# std          30.129572    2268.632997         1.004319
# min          18.250000      18.800000         0.608333
# 25%          35.425000     400.225000         1.180833
# 50%          70.300000    1391.000000         2.343333
# 75%          89.875000    3785.300000         2.995833
# max         118.750000    8684.800000         3.958333

# %% [markdown]
# ### 5. Visualización rápida

# %%
def cargos_mensuales_contrato(df):
  # Configuración del gráfico
  plt.figure(figsize=(10, 6), facecolor="#ffffff")
  ax = plt.axes()
  ax.set_facecolor("#ffffff")

  # Graficar el boxplot de la distribución de la edad por sexo biológico
  sns.boxplot(data=df_account, x='Contract', y='Charges.Monthly', hue='Contract', palette=[Carmesí, Rojo_Intenso, Púrpura_Oscuro], ax=ax, legend=False)

    # Agregar rótulos y título
  plt.title('Cargos mensuales por tipo de contrato', fontsize=18, color=Borgoña)
  plt.xlabel('')
  plt.ylabel('Cargos mensuales', fontsize=12, color=Rojo_Intenso)
  plt.xticks(fontsize=12, color=Rojo_Intenso)
  plt.yticks(fontsize=12, color=Rojo_Intenso)
  ax.spines[['top', 'right', 'left', 'bottom']].set_visible(False)
  ax.set_axisbelow(True)
  ax.yaxis.grid(color=Rosa_Claro, linestyle='--', linewidth=0.5)

    # Agregar cajas de anotación
  texto_anotacao1 = f"Mínimo = {df.groupby('Contract')['Charges.Monthly'].min().iloc[1]:.2f}\n" \
                  f"1º quartil = {df.groupby('Contract')['Charges.Monthly'].quantile(.25).iloc[1]:.2f}\n" \
                  f"2º quartil = {df.groupby('Contract')['Charges.Monthly'].median().iloc[1]:.2f}\n" \
                  f"3º quartil = {df.groupby('Contract')['Charges.Monthly'].quantile(.75).iloc[1]:.2f}\n" \
                  f"Máximo = {df.groupby('Contract')['Charges.Monthly'].max().iloc[1]:.2f}"

  texto_anotacao2 = f"Mínimo = {df.groupby('Contract')['Charges.Monthly'].min().iloc[0]:.2f}\n" \
                  f"1º quartil = {df.groupby('Contract')['Charges.Monthly'].quantile(.25).iloc[0]:.2f}\n" \
                  f"2º quartil = {df.groupby('Contract')['Charges.Monthly'].median().iloc[0]:.2f}\n" \
                  f"3º quartil = {df.groupby('Contract')['Charges.Monthly'].quantile(.75).iloc[0]:.2f}\n" \
                  f"Máximo = {df.groupby('Contract')['Charges.Monthly'].max().iloc[0]:.2f}"

  texto_anotacao3 = f"Mínimo = {df.groupby('Contract')['Charges.Monthly'].min().iloc[2]:.2f}\n" \
                  f"1º quartil = {df.groupby('Contract')['Charges.Monthly'].quantile(.25).iloc[2]:.2f}\n" \
                  f"2º quartil = {df.groupby('Contract')['Charges.Monthly'].median().iloc[2]:.2f}\n" \
                  f"3º quartil = {df.groupby('Contract')['Charges.Monthly'].quantile(.75).iloc[2]:.2f}\n" \
                  f"Máximo = {df.groupby('Contract')['Charges.Monthly'].max().iloc[2]:.2f}"

  ax.annotate(texto_anotacao1, xy=(-0.1, 45), xytext=(-0.4, 50), fontsize=10, color=Rojo_Intenso,
              bbox=dict(boxstyle="round,pad=0.3", edgecolor=Melocotón, facecolor=Rosa_Claro),
              arrowprops=dict(facecolor=Rojo_Intenso, arrowstyle="->", connectionstyle="arc3,rad=0.3"))

  ax.annotate(texto_anotacao2, xy=(0.9, 45), xytext=(0.6, 50), fontsize=10, color=Rojo_Intenso,
              bbox=dict(boxstyle="round,pad=0.3", edgecolor=Melocotón, facecolor=Rosa_Claro),
              arrowprops=dict(facecolor=Rojo_Intenso, arrowstyle="->", connectionstyle="arc3,rad=0.3"))

  ax.annotate(texto_anotacao3, xy=(2.0, 45), xytext=(2, 50), fontsize=10, color=Rojo_Intenso,
              bbox=dict(boxstyle="round,pad=0.3", edgecolor=Melocotón, facecolor=Rosa_Claro),
              arrowprops=dict(facecolor=Rojo_Intenso, arrowstyle="->", connectionstyle="arc3,rad=0.3"))

  return plt

# %%
cargos_mensuales_contrato(df_account).show()

# %%
def cargos_mensuales_metodo_pago(df):
  # Agrupar por categoría y calcular la facturación total
  facturacion_por_categoria = df.groupby('PaymentMethod')['Charges.Monthly'].sum().sort_values(ascending=False)

  # Calcular porcentaje
  total_facturacion = facturacion_por_categoria.sum()
  percentual = facturacion_por_categoria.iloc[0] / total_facturacion * 100

  # Configurações do gráfico
  plt.figure(figsize=(10, 6), facecolor= '#ffffff')
  ax = plt.axes()
  ax.set_facecolor('#ffffff')
  bars = plt.barh(facturacion_por_categoria.index, facturacion_por_categoria, color=Rojo_Intenso)

  # Agregar etiquetas y título
  plt.title('Cargos mensuales por metodo de pago', fontsize=18, color=Púrpura_Oscuro)
  plt.xlabel('')
  plt.ylabel('')
  plt.yticks(fontsize=12, color=Rosa_Intenso)
  plt.xticks([])
  ax.spines[['top', 'right', 'left', 'bottom']].set_visible(False)

  # Agregar total de facturación al lado derecho de cada barra
  for bar in bars:
      plt.text(bar.get_width() + 1, bar.get_y() + bar.get_height()/2,
              f'MXN$ {bar.get_width()/1e6:.2f} M',
              ha='left', va='center', color=Rosa_Intenso, fontsize=12)

  # Agregar texto dentro del área del gráfico
  plt.text(0.4, -1, f"$\\bf{percentual:.2f}$% de las ventas corresponden únicamente a las ventas de Electronic check.",
          ha='left', va='center', color=Púrpura_Oscuro, fontsize=12)

  return plt

# %%
cargos_mensuales_metodo_pago(df_account).show()

# %% [markdown]
# ## Limpieza de Datos para el DataFrame "CUSTOMER"

# %% [markdown]
# ### 1. Limpieza de valores categoricos

# %%
df_customer['gender'] = df_customer['gender'].replace({'Female': 1, 'Male': 0})
df_customer['SeniorCitizen'] = df_customer['SeniorCitizen'].replace({'Yes': 1, 'No': 0})

# %% [markdown]
# ### 2. Revisión de valores faltantes o inconsistencias

# %%
# Verificar valores únicos y nulos
print(df_customer[['gender', 'SeniorCitizen', 'Partner', 'Dependents']].isnull().sum())
print(df_customer['gender'].unique())
# Out:
# gender           0
# SeniorCitizen    0
# Partner          0
# Dependents       0
# dtype: int64
# [0 1]

# %% [markdown]
# ### 3. Análisis descriptivo

# %%
# Estadísticas de las columnas relevantes
print(df_customer[['SeniorCitizen', 'Partner', 'Dependents', 'tenure']].describe())
# Out:
#        SeniorCitizen      Partner   Dependents       tenure
# count    7267.000000  7267.000000  7267.000000  7267.000000
# mean        0.162653     0.484106     0.300124    32.346498
# std         0.369074     0.499782     0.458343    24.571773
# min         0.000000     0.000000     0.000000     0.000000
# 25%         0.000000     0.000000     0.000000     9.000000
# 50%         0.000000     0.000000     0.000000    29.000000
# 75%         0.000000     1.000000     1.000000    55.000000
# max         1.000000     1.000000     1.000000    72.000000

# %% [markdown]
# ### 4. Análisis exploratorio: ¿quiénes cancelan más?

# %%
# Puedes armar una paleta en lista
paleta_rosa_morado = [Rosa_Lavanda, Rosa_Claro, Rojo_Intenso, Púrpura_Oscuro]

# %%
# Seleccionar columnas numéricas relevantes
cols_corr = ['gender', 'SeniorCitizen', 'Partner', 'Dependents']
correlation = df_customer[cols_corr].corr()

sns.heatmap(correlation, annot=True, cmap=paleta_rosa_morado, fmt=".2f")
plt.title('Matriz de Correlación')
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

for i, gender in enumerate(['Female', 'Male']):
    data = df_customer[df_customer['gender'] == (0 if gender == 'Female' else 1)]
    counts = data['Partner'].value_counts(normalize=True)

    axs[i].pie(
        counts,
        labels=['No Partner', 'With Partner'],
        autopct='%1.1f%%',
        colors=[Rosa_Lavanda, Rojo_Intenso],
        startangle=90,
        explode=(0.05, 0),
        wedgeprops={'width': 0.4}
    )
    axs[i].axis('equal')
    axs[i].set_title(f'{gender} - Partner Proportion')

plt.suptitle('Distribución de Clientes con y sin Pareja por Género')
plt.show()

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final

# %% [markdown]
# ## 📌 Introducción
# Analizamos datos de clientes de Telecom X para identificar patrones asociados con la evasión (churn), con el fin de apoyar decisiones estratégicas.
#
# ## 🧹 Limpieza y Tratamiento de Datos
# - Se eliminaron duplicados
# - Se convirtieron valores textuales ("Sí"/"No") a binarios
# - Se creó la columna `Cuentas_Diarias`
# - Se normalizaron las categorías
#
# ## 📊 Análisis Exploratorio
# - Proporción de evasión: X% de clientes abandonaron el servicio.
# - Se observó mayor evasión entre clientes con contratos mensuales y métodos de pago electrónicos.
# - Factores como menor tiempo de contrato y mayor gasto mensual se correlacionan con mayor churn.
#
# ## 💡 Conclusiones e Insights
# - Los contratos de corto plazo y pagos automáticos están asociados a mayor churn.
# - Los clientes con mayor gasto mensual tienen tasas de evasión elevadas, posiblemente por expectativas no satisfechas.
#
# ## ✅ Recomendaciones
# - Ofrecer incentivos para contratos a largo plazo.
# - Implementar seguimiento a clientes con altos gastos y contratos cortos.
# - Optimizar la experiencia de usuarios con métodos de pago electrónicos.
